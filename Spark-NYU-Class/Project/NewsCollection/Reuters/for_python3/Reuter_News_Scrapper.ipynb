# %%
from bs4 import BeautifulSoup
import urllib
import csv
import re
from datetime import datetime, timedelta
import time

# %%
def getNewsContent(htmlstring):
    r = urllib.request.urlopen(htmlstring).read()
    soup = BeautifulSoup(r)

    dateTag = soup.find_all("div", attrs={"class": re.compile("ArticleHeader_date.")})
    headerTag = soup.find_all("h1", attrs={"class": re.compile("ArticleHeader_headline.")})

    date = dateTag[0].text
    header = headerTag[0].text

    articleTag = soup.find_all("div", attrs={"class": re.compile("ArticleBody_body.")})
    article = articleTag[0].text

    return date, header, article

# %%
def getUrlsFromArchiveByDate(date):
    archivePageByDate = "http://www.reuters.com/resources/archive/us/"+date+".html"
    page = urllib.request.urlopen(archivePageByDate).read()
    soup = BeautifulSoup(page)

    moduleBody = soup.find_all("div", attrs={"class":"headlineMed"})

    url_list = []

    for i in range(len(moduleBody)):
        url = moduleBody[i].a["href"]
        if ("/news/picture/" in url) or ("/news/video/" in url) or ("/pictures-report" in url) or ("/article/life-" in url):
            continue
        else:
            url_list.append(url)
            
    return url_list

# %%
def convertTimestamp(time_str):
    time_str = "JULY 12, 2017 / 1:18 PM / 10 HOURS AGO"
    time_arr = time_str.split(" / ")
    date = time_arr[0]
    hr_mi = time_arr[1]

    datetime_object = datetime.strptime(date+" "+hr_mi, '%B %d, %Y %I:%M %p')
    adjusted_EST_time = datetime_object + timedelta(hours=4)
    return str(adjusted_EST_time)

# %%
def getCsvFileByDate(date):
    urls = getUrlsFromArchiveByDate(date)
    count = 0
    with open(date+".csv", "w") as csv_file:
            for url in urls:
                try_count = 0
                while True:
                    try:
                        time_web, title, article = getNewsContent(url)
                        adjusted_time = convertTimestamp(time_web)
                        print(adjusted_time)
                        line = "\"" + adjusted_time + "\"," + "\"" + str(title.encode('utf-8')) + "\"," + "\"" + str(article.replace('\",\"', ' ').replace('\n', ' ').encode('utf-8')) + "\","
                        csv_file.write(line)
                        csv_file.write('\n')
                        count += 1
                        break
                    except:
                        print("Something wrong! try_count = "+str(try_count)+". "+url)
                        if try_count <= 2:
                            time.sleep(15)
                            try_count += 1
                        else:
                            print("URL Does Not Work! "+url)
                            break
    print(count)

# %%
# # date = "20170712" has done!
# dates = ["20170711","20170710","20170709","20170708","20170707","20170706","20170705","20170704","20170703","20170702","20170701","20170630","20170629","20170628","20170627","20170626","20170625","20170624","20170623","20170622","20170621","20170620","20170619","20170618","20170617","20170616","20170615","20170614","20170613","20170612","20170611","20170610","20170609","20170608"]
dates = ["20170711"]
for date in dates:
    getCsvFileByDate(date)
# Out:
# /home/lizichen/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/lizichen/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# Something wrong! try_count = 0. http://www.reuters.com/article/arbitration-portland-idUSL1N1K200L
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# Something wrong! try_count = 0. http://www.reuters.com/article/us-china-rights-idUSKBN19V0Q4
# Something wrong! try_count = 1. http://www.reuters.com/article/us-china-rights-idUSKBN19V0Q4
# Something wrong! try_count = 2. http://www.reuters.com/article/us-china-rights-idUSKBN19V0Q4
# Something wrong! try_count = 3. http://www.reuters.com/article/us-china-rights-idUSKBN19V0Q4
# URL Does Not Work! http://www.reuters.com/article/us-china-rights-idUSKBN19V0Q4
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# Something wrong! try_count = 0. http://www.reuters.com/article/mfs-retirement-idUSL1N1K11K9
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00
# 2017-07-12 17:18:00

# %%
htmlstring = "http://www.reuters.com/article/india-nse-stocks-idUSI8N1IW012"
with urllib.request.urlopen(htmlstring) as url:
    r = url.read()
    soup = BeautifulSoup(r)

    dateTag = soup.find_all("div", attrs={"class": re.compile("ArticleHeader_date.")})
    headerTag = soup.find_all("h1", attrs={"class": re.compile("ArticleHeader_headline.")})

    date = dateTag[0].text
    title = headerTag[0].text

    articleTag = soup.find_all("div", attrs={"class": re.compile("ArticleBody_body.")})
    article = articleTag[0].text
    
    adjusted_time = convertTimestamp(date)
            
    line = "\"" + adjusted_time + "\"," + "\"" + str(title.encode("utf-8")) + "\"," + "\"" + str(article.replace('\",\"', ' ').replace('\n', ' ').encode("utf-8")) + "\","
# Out:
# /home/lizichen/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/lizichen/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
test = "abbbbbba"
test.replace("a","b")
print(test)
# Out:
# abbbbbba
